# %% [markdown]
# # *Aufgabezettel 1*
#
# ## Aufgabe 1)
# ---

# %% [markdown]
# ### The following tasks were done with sagecell and then copied over to this jupyter file
# ### (1)
#
#     mod(54321^123456,654321)
#
# = __213423__
#
# ### (2)
#
#     gcd(123123, 456456)
#
# = __3003__
#
# ### (3)
#
#     n = 0
#     found = False
#     while not found:
#         square = n^2
#         if square > 100000:
#             print("Smallest Square Number is: "+str(square))
#             found = True
#         else:
#             n = n + 1
#
# = __Smallest Square Number is: 100489__
#
# ### (4)
#
#     n = 1
#     counter = 0
#
#     for i in range(1000):
#         num = mod(n^2, 1001)
#         if num == 23:
#             counter = counter + 1
#         n = n + 1
#
#     print(counter)
#
# = __8__
#
# ### (5)
#
#     numbers = []
#     n = 1
#
#     for i in range(60):
#         square = mod(n^2, 61)
#         if square not in numbers:
#             numbers.append(square)
#         n = n+1
#
#     print(len(numbers))
#
# = __30__
#
# ### (6)
#
#     numbers = []
#     n = 1
#
#     for i in range(60):
#         square = mod(2^n, 61)
#         if square not in numbers:
#             numbers.append(square)
#         n = n+1
#
#     print(len(numbers))
#
# = __60__

# %% [markdown]
# ---
#
# ## Aufgabe 2
#
# ---

# %% [markdown]
# ### a)
#
#     7777777777777777777777777777777777777777777*77777777777777777777777777777777777777777
#
# = __604938271604938271604938271604938271604932161728395061728395061728395061728395061729__
#
# ### b)
#
#     zahl = 60493827160493827160493827160493827160493840183950617283950617283950617283950617283951219
#
#     primfaktor = factor(zahl)
#
#     for prim in primfaktor:
#         print(prim[0], "^", prim[1])

# %% [markdown]
# ---
#
# ## Aufgabe 3
#
# ---

# %% [markdown]
# a = 0
# b = 1
# c = 2
# d = 3
# e = 4
# f = 5
# g = 6
# h = 7
# i = 8
# j = 9
# k = 10
# l = 11
# m = 12
# n = 13
# o = 14
# p = 15
# q = 16
# r = 17
# s = 18
# t = 19
# u = 20
# v = 21
# w = 22
# x = 23
# y = 24
# z = 25

# %% [markdown]
# m = leibniz
#
# c = CWISFIQ
#
# k = ?
#
#     l = 11
#     c = 2
#     26 + 2 - 11 = 17 = R
#
#     e = 4
#     w = 22
#     26 + 22 - 4 mod 26 = 18 = S
#
#     i = 8
#     i = 8
#     26 + 8 - 8 = 26 mod 26 = 0 = A
#
#     b = 1
#     s = 18
#     26 + 18 - 1 mod 26 = 17 = R
#
#     n = 13
#     f = 5
#     26 + 5 - 13 = 18 = S
#
#     i = 8
#     i = 8
#     26 + 8 - 8 = 26 mod 26 = 0 = A
#
#     z = 25
#     q = 16
#     26 + 16 - 25 mod 26 = 17 = R
#
# k = __RSA__
#
# c' = CSGISNXW
#
# k  = RSARSARS
#
# m' = ?
#
#     c = 2
#     r = 17
#     2-17 = -15 mod 26 = 11 = L
#
#     s = 18
#     s = 18
#     18-18 mod 26 = 0 = A
#
#     g = 6
#     a = 0
#     6 - 0 mod 26 = 6 = G
#
#     i = 8
#     r = 17
#     8-17 = -9 mod 26 = 17 = R
#
#     s = 18
#     s = 18
#     18-18 mod 26 = 0 = A
#
#     n = 13
#     a = 0
#     13-0 mod 26 = 13 = N
#
#     x = 23
#     r = 17
#     23 - 17 mod 26 = 6 = G
#
#     w = 22
#     s = 18
#     22-18 = 4 mod 26 = 4 = E
#
# m' = __LAGRANGE__

# %% [markdown]
# ---
# ## Aufgabe 4
# ---
