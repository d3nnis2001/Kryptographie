# %% [markdown]
# Euler Fermat nochmal lernen
#
# Aufgabe 9)
#
# $Z_18$ Quadratische Reste
#
# 1^2 mod 18 = 1
# 2^2 mod 18 = 4
# 3^2 mod 18 = 9
# 4^2 mod 18 = 16
# 5^2 mod 18 = 7
# 6^2 mod 18 = 0
# 7^2 mod 18 = 13
# 8^2 mod 18 = 10
# 9^2 mod 18 = ...
#
# Aufgabe 14)
#
# 15
#
# Wähle random Zahl von 1..13
#
# 6
#
# Check GGT von 15 und 6
#
# 15 = 6 * 2 + 3
# 6 = 3 * 2 + 0
#
# GGT = 3 != 1 Also ist es keine Primzahl
#
# Falls das nicth der Fall ist dann checken wir die Random Zahl^N-1 Mod N = 1 dann wissen wir ob wahrscheinlich eine Primzahl
#
# Aufgabe 15)
#
# N = 15
#
# Wähle zufällige Zahl machen wir mal 11
#
# 2^k*m = 2^2
#
# Falls ggT(N, a) != 0 stop ansosnten weiter hier jz ggT(15, 11) == 1 also weiter
#
# Keine Ahnugn was genau die erwarten
#
# Aufgabe 17)
#
# Shannon Entropie:
#
# Alphabet {0, 1, 2, 3}
#
# $w_1$ = 3020321113203210
#
# 3 kommt 4
# 2 kommt 4
# 1 kommt 4
# 0 kommt 4
#
# b = 4
#
# n = 16
#
# $P_0$ = 4/16 = 1/4
#
# $P_1$ = 4/16 = 1/4
#
# $P_2$ = 4/16 = 1/4
#
# $P_3$ = 4/16 = 1/4
#
# H(w) = -(1/4 * $log_4$(1/4) + $log_4$(1/4) + $log_4$(1/4) + $log_4$(1/4)) = ...
#
# ---
#
# Aufgabe 18)
#
# lim von m -> Infinity (1/m * log2 4) = lim 1/m * 2 = 2/m = 0
#
# Garkein Zufall
#
#
# Aufgabe 21)
#
# RSA:
#
# Wir haben gegeben: (N, e) = (273373, 65537)
#
# m = bielefeld
#
# m = 010804110405041103
#
# N = p * q
#
# c = m^e mod N
# c = 010804^65537 mod 273373 = ...
# c = ...
#
#
# b)
#
# Sie sind Alice. Entschlusseln Sie die Botschaft (0 ¨ , 149578, 35224)
#
# Wir nutzen zur Entschlüsselung c^d mod N
#
# Dabei müssen wir d rauskriegen welches das Inverse von e ist deswegen:
#
# Aufgabe 22)
#
# N = 1007
# Phi(N) = 936
# e = 31
#
# 0 = -q^2 + (N - Phi(N) + 1)*q - N
#   = -q^2 + (72)q - 1007
#   = q^2 - 72q + 1007
#
# 36 +- Sqrt(36^2 - 1007)
# ...
#
#
# 936 = 31 * 30 + 6     -5    151
#     31 = 6 * 5 + 1     1    -5
#     6 = 1 * 6 + 0      0    1
#
# c^d mod N
#
#
# Aufgabe 25)
#
# N = 1005973, e = 602381
#
# 1005973 = 602381 * 1 + 403592      42369  -70756
# 602381 = 403592 * 1 + 198789      -28387  42369
# 403592 = 198789 * 2 + 6014         13982  -28387
# 198789 = 6014 * 33 + 327           -423   13982
# 6014 = 327 * 18 + 128               23   -423
# 327 = 128 * 2 + 71                  -9   23
# 128 = 71 * 1 + 57                   5    -9
# 71 = 57 * 1 + 14                    -4   5
# 57 = 14 * 4 + 1                     1    -4
# 14 = 1 * 14                         0    1
#
#
#
# Aufgabe 29)
#
# 18^7 mod 101
#
#
# Aufgabe 33)
#
# Überprüfen ob eien Kurve:
#
# 4a^3 + 27b^2 != 0
#
# Dabei ist gegeben:
#
# y^2 = x^3 + 3x + 1 in F_7
#
# 4 * 3^3 + 27 * 1^2 mod 7 = 4 * 27 + 27 = 5 * 27 = 135 mod 7 = 2 != 0
#
#
#
# Aufgabe 37)
#
# Es sei E die elliptische Kurve, die durch $y^2$ = $x^3$ + x + 5 über F11 gegeben ist
#
# (a) Ein Erzeuger von E ist g = (2, 2). Die ¨offentliche Information ist (E, g). Alices geheimer Schlussel ¨
# ist a = 5, Bobs geheimer Schlussel ist ¨ b = 3. Was schickt Alice an Bob? Was schickt Bob an Alice?
# Was ist ihr gemeinsamer Schlussel ¨ k?
#
#
# g = (2, 2)
#
# a = 5, b = 3
#
# Dabei schickt alice:
#
# g = (2, 2)^5 mod 11
